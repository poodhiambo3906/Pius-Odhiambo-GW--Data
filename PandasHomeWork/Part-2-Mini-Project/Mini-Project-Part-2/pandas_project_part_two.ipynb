# %%
# Dependencies
import pandas as pd

# %%
# load CSV
new_coders = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
new_coders_pd = pd.read_csv(
    new_coders, encoding='iso-8859-1', low_memory=False)
new_coders_pd.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_coders_pd = new_coders_pd.iloc[:, [
    0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_coders_pd.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
reduced_coders_pd = reduced_coders_pd.replace({0.0: "No", 1.0: "Yes"})
reduced_coders_pd.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# 2            NaN            more than 1 million  ...
# 3            NaN            more than 1 million  ...
# 4            NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = reduced_coders_pd.loc[reduced_coders_pd["AttendedBootcamp"] == "Yes"]
attended_bootcamp.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# 97             NaN            more than 1 million  ...
# 130              3              less than 100,000  ...
# 159            NaN  between 100,000 and 1 million  ...
# 188            NaN  between 100,000 and 1 million  ...
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN
#
# [5 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
bootcamp_name = pd.DataFrame(reduced_coders_pd["BootcampName"].value_counts())

bootcamp_name.reset_index(inplace=True)
bootcamp_name.columns = ["BootcampName", "Count"]
msg = 'Free Code Camp is not a bootcamp - please scroll up and change answer to "no"'


bootcamp_name.head(50)
# Out:
#                                          BootcampName  Count
# 0                                    General Assembly     90
# 1                                     Flatiron School     54
# 2                                        Dev Bootcamp     48
# 3                                       The Iron Yard     40
# 4                               Prime Digital Academy     30
# 5                                        Hack Reactor     29
# 6                                              Turing     27
# 7                                         App Academy     22
# 8                                  Hackbright Academy     22
# 9                                             Bloc.io     21
# 10                                       Code Fellows     21
# 11                                          Galvanize     20
# 12                     New York Code + Design Academy     20
# 13                                        MakerSquare     20
# 14                                        Coding Dojo     18
# 15                               The Firehose Project     16
# 16  Free Code Camp is not a bootcamp - please scro...     15
# 17                                           Epicodus     14
# 18                                        Dev Academy     13
# 19                                  Tech Talent South     12
# 20                                     Makers Academy     12
# 21                                        Coder Camps     11
# 22                                     Launch Academy     10
# 23                                 Viking Code School     10
# 24                                        DevMountain     10
# 25                                     Software Guild     10
# 26                                             Codeup     10
# 27                                                Ada      9
# 28                                          CodeaCamp      8
# 29                                     4Geeks Academy      8
# 30                                  Startup Institute      7
# 31                                           IronHack      7
# 32                                          CodeNinja      7
# 33                           Anyone Can Learn To Code      7
# 34                                            Wyncode      6
# 35                                           Thinkful      6
# 36                                  Fullstack Academy      6
# 37                                         10x.org.il      5
# 38                                  CodeCore Bootcamp      5
# 39                                      CareerFoundry      5
# 40                          Nashville Software School      5
# 41                                      Bitmaker Labs      5
# 42                                Academia de CÃ³digo      4
# 43                                    Lighthouse Labs      4
# 44                                         Skillcrush      4
# 45                                          RefactorU      4
# 46                            Rutgers Coding Bootcamp      4
# 47                                          LAMP Camp      4
# 48                                     Codify Academy      4
# 49                                          Codesmith      4

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommend_bootcamp = attended_bootcamp.replace({"Yes": 1, "No": 0})
recommend_bootcamp = pd.DataFrame(recommend_bootcamp.groupby(
    "BootcampName")["BootcampRecommend"].sum())

recommend_bootcamp.reset_index(inplace=True)
recommend_bootcamp.columns = ["BootcampName", "Recommenders"]

recommend_bootcamp.head()
# Out:
#             BootcampName  Recommenders
# 0             10x.org.il           3.0
# 1         4Geeks Academy           4.0
# 2               AcadGild           2.0
# 3    Academia de CÃ³digo           4.0
# 4  Academic Work Academy           0.0

# %%
# Merge the two created data frames on the name of tbe bootcamp
merged_df = pd.merge(bootcamp_name, recommend_bootcamp, on="BootcampName")
merged_df.head()
# Out:
#             BootcampName  Count  Recommenders
# 0       General Assembly     90            90
# 1        Flatiron School     54            54
# 2           Dev Bootcamp     48            48
# 3          The Iron Yard     40            40
# 4  Prime Digital Academy     30            30

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
merged_df["% Recommend"] = merged_df["Recommenders"] / merged_df["Count"] * 100

# Sort results in descending order
merged_df = merged_df.sort_values(["% Recommend"], ascending=False).round(2)

# Format for percentages
merged_df["% Recommend"] = merged_df["% Recommend"].map("{0:,.2f}%".format)

merged_df.head()
# Out:
#            BootcampName  Count  Recommenders % Recommend
# 0      General Assembly     90            90     100.00%
# 79  CODEcamp Charleston      2             2     100.00%
# 92    Astro Code School      1             1     100.00%
# 91           Code Union      1             1     100.00%
# 90             Betamore      1             1     100.00%

# %%
# Export to excel and remove index
merged_df.to_excel("output/BootcampOutputPart2.xlsx", index=False)
